# %% [markdown]
# <a href="https://colab.research.google.com/github/LearnByDoing2024/Youtube/blob/main/Episode1%2C_Data_Science_Course_Structure%2C_Data_Science_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Master of University of Bologna**
# ### **Data Science and Business Analytics**

# %% [markdown]
# Here is the categorized list of subjects, organized into relevant fields with an indication of difficulty (Beginner, Intermediate, Advanced):
#
# ---
#
# ### **1. Data Science and Analytics**
#    - **Business Intelligence & Data Warehouse** (Intermediate)
#    - **Customer & Marketing Analytics** (Intermediate)
#    - **Data Mining** (Intermediate)
#    - **Statistics and Data Analysis** (Beginner)
#    - **Operation Analytics** (Intermediate)
#    - **Text Mining and Natural Language Processing** (Advanced)
#    - **Big Data Laboratory** (Advanced)
#    - **Big Data for Industry 4.0** (Advanced)
#
# ---
#
# ### **2. Machine Learning and AI**
#    - **Machine Learning** (Intermediate)
#    - **Neural Networks and Deep Learning** (Advanced)
#    - **Fundamentals of Artificial Intelligence** (Beginner)
#
# ---
#
# ### **3. Technology and Security**
#    - **Fundamentals of Cyber Security** (Beginner)
#    - **Blockchain Finance** (Intermediate)
#    - **Law and Tech** (Intermediate)
#
# ---
#
# ### **4. Business and Entrepreneurship**
#    - **Business Ethics and Sustainability** (Beginner)
#    - **Performance Measurement System** (Intermediate)
#    - **Entrepreneurial Finance** (Intermediate)
#    - **Digital Economics** (Intermediate)
#    - **Digital Transformation** (Intermediate)
#
# ---

# %% [markdown]
# ### **Episode 1:** Essential Tools for Data Science: A Beginner’s Guide
#
# ---
#
# **Introduction**
#
# Welcome to this episode where we’ll discuss the most important tools you need to become a proficient data scientist. Whether you're just starting out or transitioning into a career in data science, having a strong grip on the right tools is essential. In this episode, I’ll walk you through the fundamental toolkits and libraries that every data scientist should master. We’ll also dive into some hands-on coding to demonstrate how these tools work in real-life scenarios.
#
# Let’s get started!
#
# ---
#
# **Segment 1: The Importance of Tools in Data Science**
#
# Before we get to the code, it’s important to understand why tools are so crucial in data science. The core of data science revolves around data manipulation, analysis, and modeling. With the right tools, you can:
#
# - **Process large datasets efficiently.**
# - **Visualize data clearly for better insights.**
# - **Build machine learning models easily and quickly.**
#
# Now, let’s move on to the key tools we’ll be using throughout this episode.
#
# ---
#
# **Segment 2: The Fundamental Tools**
#
# 1. **Python**: The most widely used programming language in data science. It’s powerful yet easy to learn. Most of the tools we’ll talk about are Python libraries.
#
# 2. **NumPy**: Essential for numerical computing. It provides support for large, multi-dimensional arrays and matrices.
#
# 3. **pandas**: The go-to tool for data manipulation and analysis. You’ll use it to clean, transform, and analyze data.
#
# 4. **Matplotlib/Seaborn**: These are visualization libraries. You’ll use them to create graphs and plots, making it easier to communicate insights from your data.
#
# 5. **scikit-learn**: This is the key library for machine learning in Python. You’ll use it to build predictive models and validate them.
#
# 6. **TensorFlow/PyTorch**: If you want to go into deep learning, these are the libraries to master.
#
# ---
#
# **Segment 3: Hands-on Example**
#
# Now, let’s put everything we’ve talked about into practice. I’ve created a sample Colab notebook where you can follow along with the code to see these tools in action. We'll start by loading a dataset, preparing/cleaning it, visualizing it, and then building a simple machine learning model.
#
# ---
#
# **Conclusion**
#
# In today’s episode, we’ve covered the essential tools that will help you on your journey to becoming a data scientist. Each tool plays a critical role, and mastering them will empower you to handle any data science task effectively.
#
# Be sure to download the Colab notebook linked below and practice the hands-on coding exercises. See you in the next episode, where we’ll dive deeper into building machine learning models!

# %% [markdown]
# # Essential Tools for Data Science
# This notebook demonstrates the use of basic data science tools in Python using the California housing dataset.

# %%
# 1. Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.datasets import fetch_california_housing

# %%
# 2. Loading the California Housing dataset
housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['PRICE'] = housing.target
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  PRICE
# ...

# %%
# 3. Data exploration
print("Dataset head:")
print(df.head())
# Out:
# Dataset head:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  PRICE
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# 4. Data visualization
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
# 5. Data preprocessing
X = df.drop('PRICE', axis=1)
y = df['PRICE']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 6. Building a simple model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 7. Model evaluation
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.5305677824766758

# %%
# 8. Visualization of predictions
plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred)
plt.xlabel('True Prices')
plt.ylabel('Predicted Prices')
plt.title('True Prices vs Predicted Prices')
plt.show()
